# %%
import pandas as pd #Import pandas library

# %%
df = pd.read_csv('environmental-protection-expenditure-account-2009-2021.csv') #Read CSV file

# %%
type(df) #Type of excel file
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns #It is showing columns name
# Out:
# Index(['year', 'sector', 'class', 'cfn_tle1', 'cfn_tle2', 'units', 'magnitude',
#        'source', 'data_value', 'flag'],
#       dtype='object')

# %%
list(df.columns) #It is showing number of columns in csv file
# Out:
# ['year',
#  'sector',
#  'class',
#  'cfn_tle1',
#  'cfn_tle2',
#  'units',
#  'magnitude',
#  'source',
#  'data_value',
#  'flag']

# %%
df.head(3) #It is showing first three rows records.
# Out:
#    year              sector  class                              cfn_tle1  \
# 0  2009  Central government  Total  Environmental protection expenditure
# 1  2010  Central government  Total  Environmental protection expenditure
# 2  2011  Central government  Total  Environmental protection expenditure
#
#                         cfn_tle2       units magnitude  \
# 0  Final consumption expenditure  Proportion    Actual
# 1  Final consumption expenditure  Proportion    Actual
# 2  Final consumption expenditure  Proportion    Actual
#
#                    source  data_value flag
# 0  Environmental Accounts         1.2    F
# 1  Environmental Accounts         1.2    F
# 2  Environmental Accounts         1.1    F

# %%
df.tail()#It showing last 5 records by default.
# Out:
#      year            sector       class                              cfn_tle1  \
# 469  2016  Local government  Wastewater  Environmental protection expenditure
# 470  2017  Local government  Wastewater  Environmental protection expenditure
# 471  2018  Local government  Wastewater  Environmental protection expenditure
# 472  2019  Local government  Wastewater  Environmental protection expenditure
# 473  2020  Local government  Wastewater  Environmental protection expenditure
#
#                           cfn_tle2    units magnitude                  source  \
# 469  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 470  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 471  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 472  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 473  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
#
#      data_value flag
# ...

# %%
df.tail(3)#It is showing last 3 records
# Out:
#      year            sector       class                              cfn_tle1  \
# 471  2018  Local government  Wastewater  Environmental protection expenditure
# 472  2019  Local government  Wastewater  Environmental protection expenditure
# 473  2020  Local government  Wastewater  Environmental protection expenditure
#
#                           cfn_tle2    units magnitude                  source  \
# 471  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 472  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 473  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
#
#      data_value flag
# 471       683.0    F
# 472       780.0    F
# 473       824.0    P

# %%
df.dtypes #It is gives data type of each and every column
# Out:
# year            int64
# sector         object
# class          object
# cfn_tle1       object
# cfn_tle2       object
# units          object
# magnitude      object
# source         object
# data_value    float64
# flag           object
# dtype: object

# %%
df.columns
# Out:
# Index(['year', 'sector', 'class', 'cfn_tle1', 'cfn_tle2', 'units', 'magnitude',
#        'source', 'data_value', 'flag'],
#       dtype='object')

# %%
df['sector']
# Out:
# 0      Central government
# 1      Central government
# 2      Central government
# 3      Central government
# 4      Central government
#               ...
# 469      Local government
# 470      Local government
# 471      Local government
# 472      Local government
# 473      Local government
# Name: sector, Length: 474, dtype: object

# %%
type(df['sector'])
# Out:
# pandas.core.series.Series

# %%
list(df['sector']) #Converting sector column in list format.
# Out:
# ['Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
#  'Central government',
# ...

# %%
df.columns
# Out:
# Index(['year', 'sector', 'class', 'cfn_tle1', 'cfn_tle2', 'units', 'magnitude',
#        'source', 'data_value', 'flag'],
#       dtype='object')

# %%
df[['year']]
# Out:
#      year
# 0    2009
# 1    2010
# 2    2011
# 3    2012
# 4    2013
# ..    ...
# 469  2016
# 470  2017
# 471  2018
# 472  2019
# 473  2020
#
# [474 rows x 1 columns]

# %%
type(df[['year']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['year', 'sector', 'class', 'cfn_tle1', 'cfn_tle2', 'units', 'magnitude',
#        'source', 'data_value', 'flag'],
#       dtype='object')

# %%
df[['year','class']] #Print data from two or more columnsfrom the dataset
# Out:
#      year       class
# 0    2009       Total
# 1    2010       Total
# 2    2011       Total
# 3    2012       Total
# 4    2013       Total
# ..    ...         ...
# 469  2016  Wastewater
# 470  2017  Wastewater
# 471  2018  Wastewater
# 472  2019  Wastewater
# 473  2020  Wastewater
#
# [474 rows x 2 columns]

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 56.5 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
url_data =pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
url_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df4 = url_data[0]

# %%
df4.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df4.tail(4)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 671  170  245  135  86  17  75  115  685
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [4 rows x 30 columns]

# %%
df4.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df4.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df4['RK']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df4[['RK']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df4[['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G']]
# Out:
#       Rk          Player Pos Age   Tm   G
# 0      1      Quincy Acy  PF  24  NYK  68
# 1      2    Jordan Adams  SG  20  MEM  30
# 2      3    Steven Adams   C  21  OKC  70
# 3      4     Jeff Adrien  PF  28  MIN  17
# 4      5   Arron Afflalo  SG  29  TOT  78
# ..   ...             ...  ..  ..  ...  ..
# 670  490  Thaddeus Young  PF  26  TOT  76
# 671  490  Thaddeus Young  PF  26  MIN  48
# 672  490  Thaddeus Young  PF  26  BRK  28
# 673  491     Cody Zeller   C  22  CHO  62
# 674  492    Tyler Zeller   C  25  BOS  82
#
# [675 rows x 6 columns]

# %%
df4.to_csv("players.csv",index=False)
